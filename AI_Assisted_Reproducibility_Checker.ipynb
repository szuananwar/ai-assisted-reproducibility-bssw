# %% [markdown]
# cat << 'EOF' > notebooks/AI_Assisted_Reproducibility_Checker.ipynb
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## Reproducibility Checklist & Scoring Rubric\n",
#     "\n",
#     "| Category | Item | Points |\n",
#     "| :--- | :--- | :--- |\n",
#     "| Documentation | README with run instructions | 15 |\n",
#     "| Dependencies | requirements.txt | 15 |\n",
#     "| Environment | environment.yml | 10 |\n",
#     "| HPC Environment | spack.yaml | 10 |\n",
#     "| Testing | tests/ folder | 15 |\n",
#     "| Containerization | Dockerfile or Apptainer file | 15 |\n",
#     "| Experiment Tracking | MLflow logs or tracking file | 10 |\n",
#     "| Open Science | LICENSE file | 10 |\n",
#     "| **Total** | | **100** |\n",
#     "\n",
#     "**Score Interpretation:**\n",
#     "* **85–100:** Strong reproducibility\n",
#     "* **70–84:** Good, but improvements needed\n",
#     "* **50–69:** Moderate reproducibility risk\n",
#     "* **Below 50:** High reproducibility risk"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import os\n",
#     "\n",
#     "# Define the scoring rubric and points\n",
#     "required_items = {\n",
#     "    \"README.md\": 15,\n",
#     "    \"requirements.txt\": 15,\n",
#     "    \"environment.yml\": 10,\n",
#     "    \"tests\": 15,\n",
#     "    \"Dockerfile\": 15,\n",
#     "    \"spack.yaml\": 10,\n",
#     "    \"mlruns\": 10,\n",
#     "    \"LICENSE\": 10\n",
#     "}\n",
#     "\n",
#     "# AI-Assisted Recommendation Engine Rules\n",
#     "recommendations = {\n",
#     "    \"README.md\": \"Add a README explaining how to install, run, and reproduce the project.\",\n",
#     "    \"requirements.txt\": \"Add a requirements.txt file to document Python dependencies.\",\n",
#     "    \"environment.yml\": \"Add an environment.yml file for Conda-based reproducibility.\",\n",
#     "    \"tests\": \"Add a tests/ directory with unit or workflow tests.\",\n",
#     "    \"Dockerfile\": \"Add a Dockerfile or Apptainer recipe for portable execution.\",\n",
#     "    \"spack.yaml\": \"Add a spack.yaml file for HPC software environment reproducibility.\",\n",
#     "    \"mlruns\": \"Use MLflow or another tracking tool to record model parameters and metrics.\",\n",
#     "    \"LICENSE\": \"Add a license to clarify reuse and sharing permissions.\"\n",
#     "}\n",
#     "\n",
#     "project_path = \".\"\n",
#     "score = 0\n",
#     "missing_items = []\n",
#     "\n",
#     "# Scan the directory\n",
#     "for item, points in required_items.items():\n",
#     "    item_path = os.path.join(project_path, item)\n",
#     "    if os.path.exists(item_path):\n",
#     "        score += points\n",
#     "    else:\n",
#     "        missing_items.append(item)\n",
#     "\n",
#     "# Output Results\n",
#     "print(\"=\"*40)\n",
#     "print(f\"\\U0001f4ca Reproducibility Score: {score} / 100\")\n",
#     "print(\"=\"*40)\n",
#     "\n",
#     "if missing_items:\n",
#     "    print(\"\\n\\u274c Missing Items Detected:\")\n",
#     "    for item in missing_items:\n",
#     "         print(f\"  - {item}\")\n",
#     "            \n",
#     "    print(\"\\n\\U0001f4a1 AI-Assisted Recommendations:\")\n",
#     "    for item in missing_items:\n",
#     "        print(f\"  - {recommendations[item]}\")\n",
#     "else:\n",
#     "    print(\"\\n\\u2705 Excellent! No missing reproducibility items detected.\")"
#    ]
#   }
#  ],
#  "metadata": {
#   "language_info": {
#    "name": "python"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
# EOF
